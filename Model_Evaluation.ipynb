# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjayme049/ML/blob/main/Model_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We are about to learn R2

# %%
# 1. See the error
# P(y|x = 500) = p(x=500/y)XP(y)/(P(x=500))
# conditional probability


# for given  independent variable there will be a dependent variable

# R square = 1-SSE/SST
# SST = (yi-ybar)2 = Total varience
# SSE = (yi-yhat)2 = varience that could not be captured

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from sklearn.metrics import r2_score
# score = r2_score(y_test, y_hat)
# print(score)

# %%
# High bias model neglects the dependent and independent variable
# High varience models are too sensitive to the observation which may not be the mean.
# Varience-distance of data point from mean
# approriate fitting-Training and test error are less

# %%
import numpy as np

import matplotlib.pyplot as plot

 

# Get x values of the sine wave

time        = np.arange(0, 10, 0.1);

 

# Amplitude of the sine wave is sine of a variable like time

amplitude   = np.sin(time)

 

# Plot a sine wave using time and amplitude obtained for the sine wave

plot.plot(time, amplitude)

 

# Give a title for the sine wave plot

plot.title('Sine wave')

 

# Give x axis label for the sine wave plot

plot.xlabel('Time')

 

# Give y axis label for the sine wave plot

plot.ylabel('Amplitude = sin(time)')

 

plot.grid(True, which='both')

 

plot.axhline(y=0, color='k')

 

plot.show()

 

# Display the sine wave

plot.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42)
plt.style.use('seaborn')
x = np.linspace(0, 20, 200)
y = np.sin(x) + np.random.rand(200) + 0.1

plt.scatter(x, y)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

def PolynomialRegression(degree=2, **kwargs):
    return make_pipeline(PolynomialFeatures(degree),
                         LinearRegression(**kwargs))

# %%
model = PolynomialRegression(9)

# %%
x = x.reshape(200, 1)
print(x.shape)
# Out:
# (200, 1)

# %%
model.fit(x,y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=9)),
#                 ('linearregression', LinearRegression())])

# %%
#Predict y_hat for given x values
y_hat = model.predict(x)

plt.scatter(x.squeeze(), y)
plt.plot(x, y_hat, '--k')
